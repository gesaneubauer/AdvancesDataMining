# %%
# %run main.py -d user_movie_rating.npy -m dcs -s 1000
# Out:
# started
# parameter scan successful
# dcs
# [[     1     30      3]
#  [     1    157      3]
#  [     1    173      4]
#  ...
#  [103703  17622      2]
#  [103703  17627      4]
#  [103703  17764      4]]
# start  2023-11-26 02:10:54.890906
# start  491843.3343095
# ...
# @ Data task: Netflix Assignment
# @ Program title: RandomProjection-LSH Search Using discrete_cosine distance-func
# Attention. This program will not run more than 1800 seconds
# ...
# LSH_Search_RP_cosine started
# Built HashData in: 46.843 seconds
# threshold 0.73
# found  1
# sum_record i  5
# 0.8
# 1.0
# found  2
# sum_record i  7
# 0.7654655446197433
# 1.0
# found  3
# sum_record i  11
# 0.7454993164109749
# 0.7510676161988108
# 0.7703288865196432
# 1.0
# found  4
# sum_record i  22
# 0.7302967433402214
# 0.731310340973526
# 0.7341303483857976
# 0.741940826802374
# 0.75
# 0.7506518906054691
# 0.7542472332656507
# 0.7602631123499285
# 0.7602631123499285
# 0.7675225788801976
# 0.7675225788801976
# 0.7745966692414834
# ...
